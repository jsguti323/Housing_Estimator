# %% [markdown]
# ![Housing%20Estimator%20%282%29.svg](attachment:Housing%20Estimator%20%282%29.svg)

# %% [markdown]
# ![Housing%20Estimator%20%283%29.svg](attachment:Housing%20Estimator%20%283%29.svg)

# %% [markdown]
# ![Housing%20Estimator%20%284%29.svg](attachment:Housing%20Estimator%20%284%29.svg)

# %% [markdown]
# ![Housing%20Estimator%20%285%29.svg](attachment:Housing%20Estimator%20%285%29.svg)

# %% [markdown]
# ![Housing%20Estimator%20%286%29.svg](attachment:Housing%20Estimator%20%286%29.svg)
