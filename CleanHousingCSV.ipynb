# %%
# Import dependencies.
import pandas as pd
from citipy import citipy

# %%
# Load csv file.
file = 'Data/housing.csv'
df = pd.read_csv(file)

print(df.shape)
df.head()
# Out:
# (20640, 10)
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Extract coordinate.
lng = df["longitude"].values
lat = df['latitude'].values
lat_lng = zip(lat, lng)
coordinates = list(lat_lng)

# %%
# Create 'City' Column.
df['City'] = ""
df['City']
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 20635
# 20636
# 20637
# 20638
# 20639
# Name: City, Length: 20640, dtype: object

# %%
# Identify the nearest city for each latitude and longitude combination and add to DF.
for i, coordinate in enumerate(coordinates):
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    df['City'][i] = city

df.head()
# Out:
# /var/folders/43/dyvt9v3x5tg0cjwww0j0ygb80000gn/T/ipykernel_95351/972331100.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'][i] = city
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#        City
# 0  berkeley
# 1  piedmont
# 2  piedmont
# 3  berkeley
# 4  berkeley

# %%
# Count unique cities.
print(df['City'].nunique())
df['City'].unique()
# Out:
# 462
# array(['berkeley', 'piedmont', 'oakland', 'orinda', 'alameda',
#        'san leandro', 'moraga', 'albany', 'el cerrito', 'castro valley',
#        'ashland', 'cherryland', 'hayward', 'san lorenzo', 'fairview',
#        'union city', 'fremont', 'newark', 'milpitas', 'dublin',
#        'pleasanton', 'livermore', 'south lake tahoe', 'placerville',
#        'cameron park', 'lodi', 'chico', 'paradise', 'magalia', 'oroville',
#        'grass valley', 'yuba city', 'oakdale', 'south yuba city',
#        'woodland', 'clearlake', 'oakley', 'brentwood', 'antioch',
#        'pittsburg', 'bay point', 'concord', 'martinez', 'pleasant hill',
#        'clayton', 'walnut creek', 'alamo', 'san ramon', 'danville',
#        'lafayette', 'hercules', 'benicia', 'vallejo', 'pinole',
#        'el sobrante', 'san pablo', 'richmond', 'tiburon', 'arcata',
#        'grants pass', 'auburn', 'folsom', 'fresno', 'clovis', 'selma',
#        'kerman', 'sanger', 'reedley', 'dinuba', 'orange cove', 'parlier',
#        'kingsburg', 'lemoore', 'hanford', 'avenal', 'coalinga', 'mendota',
#        'los banos', 'red bluff', 'eureka', 'fortuna', 'brawley',
#        'mexicali', 'imperial', 'calexico', 'el centro', 'coachella',
#        'progreso', 'blythe', 'algodones', 'yuma', 'ridgecrest', 'lindsay',
#        'pahrump', 'oildale', 'bakersfield', 'lamont', 'arvin', 'fillmore',
#        'taft', 'shafter', 'wasco', 'delano', 'tehachapi',
#        'california city', 'lancaster', 'quartz hill', 'corcoran', 'ukiah',
#        'windsor', 'susanville', 'sun valley', 'burbank', 'san fernando',
#        'santa clarita', 'calabasas', 'west hollywood', 'beverly hills',
#        'santa monica', 'glendale', 'pasadena', 'south pasadena',
#        'los angeles', 'east los angeles', 'alhambra', 'monterey park',
#        'culver city', 'inglewood', 'huntington park', 'westmont',
#        'walnut park', 'willowbrook', 'west athens', 'lynwood',
#        'el segundo', 'gardena', 'carson', 'west carson', 'lomita',
#        'long beach', 'rancho palos verdes', 'la canada flintridge',
#        'claremont', 'la verne', 'san dimas', 'glendora', 'azusa',
#        'charter oak', 'pomona', 'diamond bar', 'walnut', 'covina',
#        'citrus', 'baldwin park', 'west puente valley', 'avocado heights',
#        'el monte', 'west covina', 'valinda', 'la puente',
#        'south san jose hills', 'rowland heights', 'south el monte',
#        'hacienda heights', 'duarte', 'monrovia', 'arcadia',
#        'sierra madre', 'temple city', 'rosemead', 'altadena',
#        'san marino', 'san gabriel', 'montebello', 'la habra',
#        'east la mirada', 'south whittier', 'whittier', 'pico rivera',
#        'santa fe springs', 'norwalk', 'la mirada', 'buena park',
#        'commerce', 'bell gardens', 'bell', 'maywood', 'cudahy',
#        'south gate', 'downey', 'paramount', 'compton', 'signal hill',
#        'bellflower', 'lakewood', 'cerritos', 'la palma', 'artesia',
#        'hawaiian gardens', 'los alamitos', 'rossmoor', 'seal beach',
#        'lennox', 'hawthorne', 'lawndale', 'alondra park',
#        'manhattan beach', 'hermosa beach', 'redondo beach',
#        'palos verdes estates', 'torrance', 'agoura hills',
#        'westlake village', 'malibu', 'adelanto', 'palmdale', 'madera',
#        'chowchilla', 'novato', 'san rafael', 'san anselmo', 'larkspur',
#        'corte madera', 'mill valley', 'petaluma', 'rohnert park',
#        'merced', 'livingston', 'turlock', 'atwater', 'patterson',
#        'altamont', 'salinas', 'watsonville', 'marina', 'gonzales',
#        'seaside', 'soledad', 'greenfield', 'king city', 'monterey',
#        'pacific grove', 'napa', 'american canyon', 'sonoma', 'santa rosa',
#        'north auburn', 'truckee', 'brea', 'fullerton', 'placentia',
#        'yorba linda', 'chino hills', 'tustin foothills', 'mission viejo',
#        'lake forest', 'corona', 'rancho santa margarita', 'laguna hills',
#        'san juan capistrano', 'laguna niguel', 'san clemente',
#        'dana point', 'irvine', 'tustin', 'laguna beach', 'aliso viejo',
#        'laguna woods', 'costa mesa', 'newport beach', 'fountain valley',
#        'santa ana', 'orange', 'garden grove', 'anaheim', 'stanton',
#        'cypress', 'westminster', 'huntington beach', 'rocklin',
#        'orangevale', 'citrus heights', 'roseville', 'north highlands',
#        'lincoln', 'grand terrace', 'rubidoux', 'riverside', 'pedley',
#        'glen avon', 'mira loma', 'norco', 'moreno valley', 'perris',
#        'lake elsinore', 'sun city', 'canyon lake', 'hemet', 'san jacinto',
#        'wildomar', 'murrieta', 'temecula', 'east hemet', 'yucaipa',
#        'beaumont', 'banning', 'palm springs', 'rancho mirage',
#        'cathedral city', 'la quinta', 'desert hot springs', 'palm desert',
#        'indio', 'twentynine palms', 'sacramento', 'rosemont', 'florin',
#        'west sacramento', 'la riviera', 'carmichael', 'rio linda',
#        'foothill farms', 'fair oaks', 'rancho cordova', 'elk grove',
#        'galt', 'hollister', 'gilroy', 'chino', 'montclair', 'upland',
#        'rancho cucamonga', 'ontario', 'fontana', 'bloomington', 'rialto',
#        'san bernardino', 'crestline', 'colton', 'highland', 'loma linda',
#        'redlands', 'barstow', 'apple valley', 'victorville', 'hesperia',
#        'yucca valley', 'lake havasu city', 'bullhead city', 'san diego',
#        'lemon grove', 'national city', 'la mesa', 'la presa', 'bonita',
#        'chula vista', 'coronado', 'solana beach', 'poway',
#        'imperial beach', 'tijuana', 'spring valley', 'rancho san diego',
#        'el cajon', 'bostonia', 'lakeside', 'alpine', 'santee',
#        'escondido', 'encinitas', 'san marcos', 'carlsbad', 'oceanside',
#        'vista', 'fallbrook', 'ramona', 'tecate', 'la joya',
#        'san francisco', 'daly city', 'south san francisco', 'stockton',
#        'country club', 'garden acres', 'lathrop', 'riverbank', 'ripon',
#        'manteca', 'tracy', 'atascadero', 'morro bay', 'san luis obispo',
#        'arroyo grande', 'pismo beach', 'grover beach', 'santa maria',
#        'pacifica', 'san bruno', 'millbrae', 'hillsborough', 'burlingame',
#        'san mateo', 'belmont', 'foster city', 'san carlos',
#        'redwood city', 'menlo park', 'east palo alto', 'palo alto',
#        'stanford', 'los altos hills', 'half moon bay', 'goleta',
#        'santa barbara', 'carpinteria', 'lompoc', 'isla vista', 'san jose',
#        'santa clara', 'campbell', 'east foothills', 'mountain view',
#        'sunnyvale', 'cupertino', 'saratoga', 'los gatos', 'los altos',
#        'morgan hill', 'scotts valley', 'santa cruz', 'soquel', 'aptos',
#        'capitola', 'redding', 'shasta lake', 'anderson', 'reno',
#        'klamath falls', 'fairfield', 'suisun city', 'vacaville', 'dixon',
#        'roseland', 'healdsburg', 'modesto', 'ceres', 'olivehurst',
#        'exeter', 'visalia', 'farmersville', 'tulare', 'porterville',
#        'simi valley', 'santa paula', 'oxnard', 'port hueneme',
#        'camarillo', 'moorpark', 'thousand oaks', 'davis', 'marysville',
#        'linda'], dtype=object)

# %%
# View columms with null values.
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# City                    0
# dtype: int64

# %%
# Drop rows with nulls values.
df = df.dropna()

# %%
# Verify no null values remaining.
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# City                  0
# dtype: int64

# %%
# Check to see if there are duplicate rows.
df.duplicated().sum()
# Out:
# 0

# %%
#Rename columns.
df = df.rename(columns={
    'longitude': 'Longitude',
    'latitude': 'Lattitude',
    'housing_median_age': 'Median Age',
    'total_rooms': 'Total Rooms',
    'total_bedrooms': 'Bedrooms',
    'population': 'Population',
    'households': 'Households',
    'median_income': 'Median Income',
    'median_house_value': 'Median House Value',
    'ocean_proximity': 'Ocean Proximity'
})

df.head()
# Out:
#    Longitude  Lattitude  Median Age  Total Rooms  Bedrooms  Population  \
# 0    -122.23      37.88        41.0        880.0     129.0       322.0
# 1    -122.22      37.86        21.0       7099.0    1106.0      2401.0
# 2    -122.24      37.85        52.0       1467.0     190.0       496.0
# 3    -122.25      37.85        52.0       1274.0     235.0       558.0
# 4    -122.25      37.85        52.0       1627.0     280.0       565.0
#
#    Households  Median Income  Median House Value Ocean Proximity      City
# 0       126.0         8.3252            452600.0        NEAR BAY  berkeley
# 1      1138.0         8.3014            358500.0        NEAR BAY  piedmont
# 2       177.0         7.2574            352100.0        NEAR BAY  piedmont
# 3       219.0         5.6431            341300.0        NEAR BAY  berkeley
# 4       259.0         3.8462            342200.0        NEAR BAY  berkeley

# %%
# Reorder Columns
df = df[['City', 'Longitude', 'Lattitude', 'Population', 'Median Age', 'Median Income', 'Median House Value', 'Total Rooms', 'Bedrooms', 'Households', 'Ocean Proximity']]

df.head()
# Out:
#        City  Longitude  Lattitude  Population  Median Age  Median Income  \
# 0  berkeley    -122.23      37.88       322.0        41.0         8.3252
# 1  piedmont    -122.22      37.86      2401.0        21.0         8.3014
# 2  piedmont    -122.24      37.85       496.0        52.0         7.2574
# 3  berkeley    -122.25      37.85       558.0        52.0         5.6431
# 4  berkeley    -122.25      37.85       565.0        52.0         3.8462
#
#    Median House Value  Total Rooms  Bedrooms  Households Ocean Proximity
# 0            452600.0        880.0     129.0       126.0        NEAR BAY
# 1            358500.0       7099.0    1106.0      1138.0        NEAR BAY
# 2            352100.0       1467.0     190.0       177.0        NEAR BAY
# 3            341300.0       1274.0     235.0       219.0        NEAR BAY
# 4            342200.0       1627.0     280.0       259.0        NEAR BAY

# %%
# Export the DataFrame as a CSV file
output_data_file = "Data/Clean_Housing.csv"
# Export the City_Data into a CSV.
df.to_csv(output_data_file)
