# %%
import pandas as pd
import matplotlib as plt

# %%
file_path = "../Data/clean_merged_data.csv"
clean_merged_df = pd.read_csv(file_path)
clean_merged_df
# Out:
#                 City  Longitude  latitude  Population  median_age  \
# 0      Mission Viejo    -117.66     33.61         789          16
# 1      Mission Viejo    -117.66     33.62        1962          16
# 2      Mission Viejo    -117.67     33.61        1972          24
# 3      Mission Viejo    -117.66     33.61        1713          17
# 4      Mission Viejo    -117.66     33.61         860          21
# ...              ...        ...       ...         ...         ...
# 11448    Yorba Linda    -117.79     33.84        4005           9
# 11449    Yorba Linda    -117.78     33.85        1665          16
# 11450    Yorba Linda    -117.78     33.86        2146          16
# 11451    Yorba Linda    -117.77     33.85        2061          13
# 11452    Yorba Linda    -117.77     33.84        1913           5
#
#        median_income  median_house_value  total_rooms  Bedrooms  Households  \
# 0             8.4112              286900         2022       254         270
# ...

# %%
fig = clean_merged_df.hist(figsize = [70,90],grid= True, legend= True,xlabelsize=25,ylabelsize=25,ec='k')
y=[x.title.set_size(32) for x in fig.ravel()]
